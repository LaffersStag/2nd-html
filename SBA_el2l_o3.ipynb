# %% [markdown]
# <a href="https://colab.research.google.com/github/LaffersStag/2nd-html/blob/main/SBA_el2l_o3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install -U "pandas==2.2.2"

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
# !pip -q install -U openai numpy scikit-learn umap-learn tiktoken

# %%
# !ls -lah
# Out:
# total 540K
# drwxr-xr-x 1 root root 4.0K Jan 21 20:08 .
# drwxr-xr-x 1 root root 4.0K Jan 21 19:31 ..
# -rw-r--r-- 1 root root  28K Jan 21 20:08 colab_harness_recup_sba.py
# drwxr-xr-x 4 root root 4.0K Jan 16 14:24 .config
# -rw-r--r-- 1 root root  27K Jan 21 19:41 mapping_table.jsonl
# -rw-r--r-- 1 root root 2.0K Jan 21 19:41 mapping_table_top20.md
# -rw-r--r-- 1 root root  51K Jan 21 19:41 pages_claim_v2.jsonl
# -rw-r--r-- 1 root root  53K Jan 21 19:41 pages_frame_v2.jsonl
# -rw-r--r-- 1 root root  71K Jan 21 19:41 pages_mixed_v2.jsonl
# -rw-r--r-- 1 root root 253K Jan 21 19:45 pages_proof_v2.jsonl
# -rw-r--r-- 1 root root  21K Jan 21 19:41 pages_support_v2.jsonl
# -rw-r--r-- 1 root root  795 Jan 21 19:41 reclassification_report.json
# drwxr-xr-x 1 root root 4.0K Jan 16 14:24 sample_data

# %%
import os
from google.colab import userdata

key = userdata.get("OPENAI_API_KEY")  # Name des Secrets in Colab
assert key and key.startswith(("sk-", "sess-")), "Secret OPENAI_API_KEY nicht gefunden oder sieht falsch aus."
os.environ["OPENAI_API_KEY"] = key

print("✅ OPENAI_API_KEY gesetzt (gekürzt):", key[:6] + "..." + key[-4:])
# Out:
# ✅ OPENAI_API_KEY gesetzt (gekürzt): sk-pro...4SkA

# %%
# !python colab_harness_recup_sba.py
# Out:
# 2026-01-21 20:11:50.651286: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-21 20:11:50.656194: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-21 20:11:50.682598: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769026310.706086    9825 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769026310.713013    9825 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
